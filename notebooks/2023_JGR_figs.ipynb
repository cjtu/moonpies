# %% [markdown]
# # Plot Figures for JGR: Planets 2023 paper
#
# See code in plot_figs.py. Figures were run on moonpies v1.1.0 and figures plotting model results require running the model with seeds 1-10000 and supplying the path to the model output rundate "datedir" directory (typically `datedir='./out/datedir'`).

# %%
import plot_figs as pf

# %%
# Figure 2
_ = pf.crater_basin_ages(fsave=False)

# %%
# Figure 3
_ = pf.ejecta_distance(fsave=False)

# %%
# Figure 4
_ = pf.volatilized_fraction_bsed(fsave=False)

# %%
# Figure 6 
_ = pf.plot_by_module(fsave=False, seeds=range(100))

# %%
# Figure 7
datedir = '/home/ctaiudovicic/projects/moonpies/out/230202/'
_ = pf.strat_cols_seeds(fsave=False, datedir=datedir)

# %%
# Figure 8
_ = pf.strat_cols_bsed(fsave=False, datedir=datedir)

# %%
# Figure 9
_ = pf.compare_violin(fsave=False)
# Out:
# Loading aggregated data from ../out/230202

# %%
# Figure 10
_ = pf.kde_layers(fsave=False)
# Out:
# Loading aggregated data from ../out/230202

# %%
# Figure 11
_ = pf.surface_boxplot(fsave=False)
# Out:
# Loading aggregated data from /home/ctaiudovicic/projects/moonpies/out/230202
