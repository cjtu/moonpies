# %% [markdown]
# # Plot Supplementary Figures for JGR: Planets 2023 paper
#
# See code in plot_figs.py. Figures were run on moonpies v1.1.0 and figures plotting model results require running the model with seeds 1-10000 and supplying the path to the model output rundate "datedir" directory (typically `datedir='./out/datedir'`).

# %%
import plot_figs as pf

# %%
# Figure S1
_ = pf.ballistic_hop(fsave=False)
# Out:
# Figure saved to /home/ctaiudovicic/projects/moonpies/figure_scripts/out/230330/figures/230330_v1.1.0/bhop_lat.png

# %%
# Figure S2
_ = pf.ast_comet_vels(fsave=False)
# Out:
# Figure saved to /home/ctaiudovicic/projects/moonpies/figure_scripts/out/230330/figures/230330_v1.1.0/comet_vels.png

# %%
# Figure S3
_ = pf.ice_retention(fsave=False)
# Out:
# Figure saved to /home/ctaiudovicic/projects/moonpies/figure_scripts/out/230330/figures/230330_v1.1.0/ice_retention.png

# %%
# Figure S4
_ = pf.basin_ice(fsave=False)
# Out:
# Figure saved to /home/ctaiudovicic/projects/moonpies/figure_scripts/out/230330/figures/230330_v1.1.0/basin_ice.png

# %%
# Figure S5
_ = pf.bsed_sensitivity_violin(fsave=False)
# Out:
# Loading aggregated data from ../out/230202
# Figure saved to /home/ctaiudovicic/projects/moonpies/figure_scripts/out/230330/figures/230330_v1.1.0/bsed50_violin.png

# %%
# Figure S6
_ = pf.comet_sensitivity_violin(fsave=False)
# Out:
# Loading aggregated data from ../out/230202
# Figure saved to /home/ctaiudovicic/projects/moonpies/figure_scripts/out/230330/figures/230330_v1.1.0/comet_violin.png

# %%
# Figure S7
pct = pf.ice_pct_fig7(fsave=False)
pct
# Out:
# <style type="text/css">
# #T_b0006_row0_col0 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_b0006_row0_col1, #T_b0006_row3_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_b0006_row0_col2 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_b0006_row0_col3, #T_b0006_row5_col6 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_b0006_row0_col4, #T_b0006_row1_col6, #T_b0006_row3_col7 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b0006_row0_col5, #T_b0006_row6_col4 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_b0006_row0_col6, #T_b0006_row1_col5, #T_b0006_row2_col3, #T_b0006_row2_col4, #T_b0006_row2_col6, #T_b0006_row2_col7, #T_b0006_row5_col3, #T_b0006_row8_col1, #T_b0006_row8_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b0006_row0_col7 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# ...

# %%
# Figure S8
pct_top, pct_bot = pf.ice_pct_fig8(fsave=False)
pct_top
# Out:
# <style type="text/css">
# #T_bfdcf_row0_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_bfdcf_row0_col1, #T_bfdcf_row0_col8 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_bfdcf_row0_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_bfdcf_row0_col3 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_bfdcf_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_bfdcf_row0_col5 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_bfdcf_row0_col6, #T_bfdcf_row8_col2 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_bfdcf_row0_col7 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_bfdcf_row0_col9 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# ...

# %%
# Figure S8b
pct_bot
# Out:
# <style type="text/css">
# #T_61300_row0_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_61300_row0_col1, #T_61300_row0_col8 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_61300_row0_col2 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_61300_row0_col3 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_61300_row0_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_61300_row0_col5 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_61300_row0_col6 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_61300_row0_col7 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_61300_row0_col9 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# ...

# %%
# Figure S9
_ = pf.grid_plots(fsave=False)
# Out:
# Figure saved to /home/ctaiudovicic/projects/moonpies/figure_scripts/out/230330/figures/230330_v1.1.0/grid_plots.png

# %%
# Figure S10
_ = pf.plot_by_module_time(fsave=False)
# Out:
# Figure saved to /home/ctaiudovicic/projects/moonpies/figure_scripts/out/230330/figures/230330_v1.1.0/plot_by_module_time.png
