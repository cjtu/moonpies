# %%
import moonpies as mp
import default_config
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import default_config
cfg = default_config.Cfg()

# %%
ddir = '/home/cjtu/projects/moonpies/data/210804_mpies/98830/'

# Get age from crater list
crater_list = mp.get_crater_list(cfg)

# Read coldtrap strat.csv 
coldtrap = 'Cabeus B'
df = pd.read_csv(ddir + coldtrap + '_strat.csv')

# make cutoff for coldtrap its max possible age since i didn't save these out
crater = crater_list[crater_list['cname'] == coldtrap]
maxage = (crater.age + crater.age_upp).values[0]
# maxage = 4.16e9  # Set here if known, else use maxage from above
df_since_formation = df[df.time < maxage]
print(maxage)
df_since_formation.head()
# Out:
# 4010000128.0
#     label          time         ice     ejecta      depth    icepct
# 3     Ice  4.000000e+09  170.837550   0.000000  372.63232  100.0000
# 4  Cabeus  3.960000e+09    7.737881  33.573154  201.79475   18.7308
# 5     Ice  1.270000e+09  160.483720   0.000000  160.48372  100.0000

# %%
maxage
# Out:
# 0    4.200000e+09
# dtype: float64

# %%
f, ax = plt.subplots(figsize=(8/2, 5/2))
v = np.arange(70)*1000
ong_x = [10, 15, 30, 45, 60]
ong_y = [1, 1.97E-01, 1.47E-02, 1.93E-03, 6.60E-06]
retention_c = mp.ice_retention_factor(v, 'cannon')
retention_m = mp.ice_retention_factor(v, 'moonpies')
plt.plot(ong_x, ong_y, 'o', label='Ong et al. (2010)')
plt.semilogy(v/1000, retention_c, label='mode=cannon')
plt.semilogy(v/1000, retention_m, label='mode=moonpies')
plt.title('Ice Retention vs Impact Speed')
plt.ylabel('Ice Retention Fraction [0-1]')
plt.xlabel('Impact Speed [km/s]')
plt.ylim(1E-6, 1.5)
plt.xlim(0, 65)
mp.plot_version(cfg, loc='ur')
plt.legend()
plt.savefig('/home/cjtu/projects/moonpies/figs/ice_retention.png', dpi=300)

# %%
cfg = default_config.Cfg()
x = np.linspace(0, 70e3, 70)
jfc_speeds = mp.gaussian(x, cfg.jfc_speed_mean, cfg.jfc_speed_sd) 
lpc_speeds = mp.gaussian(x, cfg.lpc_speed_mean, cfg.lpc_speed_sd)
speeds = cfg.jfc_to_lpc_ratio * jfc_speeds + lpc_speeds
speed_prob = speeds/np.sum(speeds)
plt.plot(x, 18000*speeds)

# %%
# moonpies
def_cfg = default_config.Cfg(mode='moonpies')
rng = mp.get_rng(def_cfg)
time_arr = mp.get_time_array(def_cfg)
ice = mp.get_impact_ice(time_arr, df, def_cfg, rng=rng)
plt.plot(time_arr, ice)
plt.xlim(time_arr.max(), time_arr.min())
plt.show()

# %%
# cannon mode
can_cfg = default_config.Cfg(mode='cannon', impact_ice_basins=True)

rng = mp.get_rng(can_cfg)
time_arr = mp.get_time_array(can_cfg)
ice = mp.get_impact_ice(time_arr, df, can_cfg, rng=rng)
plt.plot(time_arr, ice)
plt.xlim(time_arr.max(), time_arr.min())
plt.show()

# %%
# Keep seed the same, test different parameters
out = []
densities = [950, 1300, 1500, 2000]
for mydensity in densities:
    print('Starting density', mydensity)
    cfg = default_config.Cfg(seed=20, write=False, ice_density=mydensity)
    print(cfg.ice_density)
    out.append(mp.main(cfg))
# Out:
# Starting density 950
# 950.0
# Starting density 1300
# 1300.0
# Starting density 1500
# 1500.0
# Starting density 2000
# 2000.0

# %%
# Get outputs (ejecta dataframe, ice dataframe, strat dataframe dict)
# To get a strat dataframe, do cold trap in [""]:
ej, ice, strat_dict = out[0]
strat_dict['Haworth'].head(8)
# Out:
#                 label          time        ice      ejecta       depth  \
# 0  Amundsen-Ganswindt  4.250000e+09   6.570244  225.899979  576.428833
# 1                 Ice  4.160000e+09  43.022240    0.000000  343.958588
# 2           Shoemaker  4.150000e+09   5.636763   24.339754  300.936340
# 3                 Ice  4.130000e+09   6.193049    0.000000  270.959839
# 4      Mendel-Rydberg  4.120000e+09   3.919610   31.403051  264.766785
# 5                 Ice  3.910000e+09  43.325039    0.000000  229.444107
# 6            Amundsen  3.900000e+09   0.354867   10.181757  186.119064
# 7                 Ice  3.890000e+09   0.063701    0.000000  175.582443
#
#      icepct
# 0    2.8263
# 1  100.0000
# 2   18.8039
# 3  100.0000
# 4   11.0966
# 5  100.0000
# 6    3.3679
# 7  100.0000

# %%
# stats on many strat column outputs
for i, dens in enumerate(densities):
    means = []
    ej, ice, strat_dict = out[i]

    # Get and plot mean of all strat columns in strat_dict
    for key in strat_dict:
        df = strat_dict[key]
        means.append(np.median(df.ice))
    plt.plot(means, label=dens)

plt.legend()

# %%
# Keep params the same, test different seeds
out = []
for myseed in [1, 45, 75647, 23452]:
    cfg = default_config.Cfg(seed=myseed, write=False)
    out.append(mp.main(cfg))

# %%
# cfg = default_config.Cfg(seed=12345, write=False, timestep=1e6)
# out = mp.main(cfg)
